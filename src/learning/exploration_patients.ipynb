# %%
import pandas as pd
from sklearn import preprocessing
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import *
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from pylab import rcParams
import copy

import matplotlib
from sklearn.metrics import RocCurveDisplay
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.neighbors import KNeighborsClassifier
from sklearn import metrics
from sklearn.model_selection import StratifiedKFold, GridSearchCV
from sklearn.ensemble import RandomForestClassifier

# %%
path = "/home/mfmezger/data/AI_Clinic_Data/NORA_EXPORT/patients_features.csv"

df = pd.read_csv(path,)

df.head()
# Out:
#    Unnamed: 0  Gruppe Image  firstorder_10Percentile  firstorder_90Percentile  \
# 0           0       1    AT                15.000000               130.333333
# 1           1       1    BG                -4.800000                98.233333
# 2           2       1    BH                35.600000               177.666667
# 3           3       2    EG                46.500000               110.500000
# 4           4       3    FG                49.533333                98.666667
#
#    firstorder_Energy  firstorder_Entropy  firstorder_InterquartileRange  \
# 0       5.303353e+07            2.287477                      72.333333
# 1       6.471675e+06            2.576310                      50.000000
# 2       1.120756e+07            3.048903                      84.750000
# 3       1.012544e+08            2.158269                      33.000000
# 4       7.141937e+07            1.868863                      25.000000
#
#    firstorder_Kurtosis  firstorder_Maximum  ...  \
# 0            16.190133          303.333333  ...
# 1             3.691889          136.333333  ...
# 2             2.750291          294.333333  ...
# 3             4.483693          173.000000  ...
# 4            16.662601          203.666667  ...
#
#    shape_Maximum2DDiameterColumn  shape_Maximum2DDiameterRow  \
# 0                      36.246272                   39.365565
# 1                      29.418343                   31.460798
# 2                      20.137708                   23.410549
# 3                      55.724196                   52.793601
# 4                      59.847388                   46.457050
#
#    shape_Maximum2DDiameterSlice  shape_Maximum3DDiameter  shape_MeshVolume  \
# 0                     36.116828                42.219042      14605.323474
# 1                     23.062575                33.581700       4181.742668
# 2                     18.351658                23.938229       1612.623533
# 3                     57.668894                63.320705      38169.682026
# 4                     47.050257                62.552279      34058.888753
#
#    shape_MinorAxisLength  shape_Sphericity  shape_SurfaceArea  \
# 0              27.694685          0.670818        4345.714797
# 1              17.269831          0.720193        1737.081653
# 2              12.451577          0.709901         931.717646
# 3              37.002193          0.680302        8033.691939
# 4              33.026480          0.665879        7913.319239
#
#    shape_SurfaceVolumeRatio  shape_VoxelVolume
# 0                  0.298538       14686.584473
# 1                  0.434335        4244.804382
# 2                  0.596498        1657.485962
# 3                  0.215247       38301.944733
# 4                  0.256929       34209.251404
#
# [5 rows x 110 columns]

# %%
df = df.drop(["Image", "Unnamed: 0"], axis=1)

# %%
df.head(16)
# Out:
#     Gruppe  firstorder_10Percentile  firstorder_90Percentile  \
# 0        1                15.000000               130.333333
# 1        1                -4.800000                98.233333
# 2        1                35.600000               177.666667
# 3        2                46.500000               110.500000
# 4        3                49.533333                98.666667
# 5        2                 1.333333               184.166667
# 6        1                46.333333               105.333333
# 7        2                21.666667                84.666667
# 8        3                11.950000               103.000000
# 9        2                48.000000               103.500000
# 10       3                41.666667                88.000000
# 11       1               -21.366667                98.666667
# 12       3                23.666667                87.400000
# 13       2                 0.333333               108.333333
# 14       3                 8.333333                79.333333
#
#     firstorder_Energy  firstorder_Entropy  firstorder_InterquartileRange  \
# 0        5.303353e+07            2.287477                      72.333333
# 1        6.471675e+06            2.576310                      50.000000
# 2        1.120756e+07            3.048903                      84.750000
# 3        1.012544e+08            2.158269                      33.000000
# 4        7.141937e+07            1.868863                      25.000000
# 5        5.284705e+07            3.327202                      79.666667
# 6        9.812075e+07            2.009039                      29.666667
# 7        1.114973e+07            2.107497                      32.666667
# 8        3.069490e+06            2.602458                      49.375000
# 9        2.823748e+07            1.966116                      25.000000
# 10       2.104660e+07            1.783721                      23.333333
# 11       3.028806e+06            2.851984                      64.750000
# 12       1.032432e+07            2.139848                      32.333333
# 13       1.613468e+07            2.638106                      54.166667
# 14       1.245905e+07            2.242229                      36.333333
#
#     firstorder_Kurtosis  firstorder_Maximum  firstorder_Mean  \
# 0             16.190133          303.333333        71.462075
# 1              3.691889          136.333333        56.687937
# 2              2.750291          294.333333       111.593675
# 3              4.483693          173.000000        78.711733
# 4             16.662601          203.666667        74.621760
# 5             36.926776          890.333333        88.315517
# 6             19.353264          425.000000        76.484769
# 7              7.013800          216.000000        53.726332
# 8             11.640448          139.000000        57.078135
# 9             16.602893          155.500000        77.282738
# 10            62.852462          179.333333        64.045103
# 11             3.008030          148.333333        43.722850
# 12            13.097063          143.666667        56.598239
# 13             3.785859          148.666667        63.355441
# 14            24.301661          325.000000        45.586051
#
#     firstorder_MeanAbsoluteDeviation  ...  shape_Maximum2DDiameterColumn  \
# 0                          38.156397  ...                      36.246272
# 1                          32.708582  ...                      29.418343
# 2                          45.473425  ...                      20.137708
# 3                          20.482707  ...                      55.724196
# 4                          16.379994  ...                      59.847388
# 5                          69.326957  ...                      27.065751
# 6                          18.452930  ...                      51.442214
# 7                          20.477627  ...                      31.703827
# 8                          30.722192  ...                      21.316430
# 9                          18.825654  ...                      40.637328
# 10                         15.782781  ...                      38.751412
# 11                         37.328453  ...                      24.930672
# 12                         20.973945  ...                      26.023764
# 13                         33.223081  ...                      21.876107
# 14                         22.611894  ...                      43.391308
#
#     shape_Maximum2DDiameterRow  shape_Maximum2DDiameterSlice  \
# 0                    39.365565                     36.116828
# 1                    31.460798                     23.062575
# 2                    23.410549                     18.351658
# 3                    52.793601                     57.668894
# 4                    46.457050                     47.050257
# 5                    28.125349                     23.734316
# 6                    54.534442                     47.348145
# 7                    32.496834                     25.460579
# 8                    20.082086                     18.302776
# 9                    35.045052                     41.385170
# 10                   39.131290                     36.019606
# 11                   24.801908                     27.683394
# 12                   28.088658                     25.332268
# 13                   41.346484                     31.195961
# 14                   48.170296                     42.379705
#
#     shape_Maximum3DDiameter  shape_MeshVolume  shape_MinorAxisLength  \
# 0                 42.219042      14605.323474              27.694685
# 1                 33.581700       4181.742668              17.269831
# 2                 23.938229       1612.623533              12.451577
# 3                 63.320705      38169.682026              37.002193
# 4                 62.552279      34058.888753              33.026480
# 5                 40.836546       5258.003871              17.127980
# 6                 57.428926      51835.616430              36.548671
# 7                 35.706870       9678.284327              19.750971
# 8                 23.874213       1648.366451              12.303117
# 9                 48.541617      11818.706989              27.383870
# 10                42.630455      12235.601743              27.729467
# 11                31.643198       3349.423409              16.408657
# 12                29.336825       6418.983142              19.911560
# 13                45.327127       5238.215129              15.620683
# 14                53.567652      12301.365534              30.494362
#
#     shape_Sphericity  shape_SurfaceArea  shape_SurfaceVolumeRatio  \
# 0           0.670818        4345.714797                  0.298538
# 1           0.720193        1737.081653                  0.434335
# 2           0.709901         931.717646                  0.596498
# 3           0.680302        8033.691939                  0.215247
# 4           0.665879        7913.319239                  0.256929
# 5           0.680676        2170.573705                  0.422970
# 6           0.609419       13687.177026                  0.282828
# 7           0.720898        3049.014402                  0.438773
# 8           0.711346         930.291420                  0.614447
# 9           0.663750        3779.542671                  0.320033
# 10          0.696637        3687.321446                  0.303336
# 11          0.655762        1473.203506                  0.587846
# 12          0.717158        2084.464689                  0.474343
# 13          0.661237        2208.174167                  0.469483
# 14          0.606200        4775.717892                  0.376428
#
#     shape_VoxelVolume
# 0        14686.584473
# 1         4244.804382
# 2         1657.485962
# 3        38301.944733
# 4        34209.251404
# 5         5335.807800
# 6        51473.617554
# 7         9754.180908
# 8         1692.295074
# 9        11916.160583
# 10       12328.147888
# 11        3414.154053
# 12        6478.309631
# 13        5315.780640
# 14       12344.360352
#
# [15 rows x 108 columns]

# %% [markdown]
# # Multidimensional Scaling

# %%
from sklearn.manifold import MDS
from sklearn.metrics import euclidean_distances

# %%
y = df['Gruppe']
X = df.drop(["Gruppe"], axis=1)
#X = preprocessing.normalize(X)
x = np.array(X)

# %%
similarities = euclidean_distances(x)


seed = np.random.RandomState(seed=3)

mds = MDS(n_components=2, max_iter=5000, eps=1e-12, random_state=seed,
                   n_init=10,
                   dissimilarity="precomputed", n_jobs=1, metric=False)
pos = mds.fit_transform(similarities)

# %%
# Plot

from matplotlib import pyplot as plt
from matplotlib.collections import LineCollection
import matplotlib.cm as cm


fig = plt.figure(1)
ax = plt.axes([0., 0., 1., 1.])

s = 100

# Type of tumor
a = [0,1,2,6,11]
b = [3,5,7,9,13]
c = [4,8,10,12,14]

plt.scatter(pos[a, 0], pos[a, 1], color='navy', alpha=1.0, s=s, lw=1, label='A')
plt.scatter(pos[b, 0], pos[b, 1], color='turquoise', alpha=1.0, s=s, lw=1, label='B')
plt.scatter(pos[c, 0], pos[c, 1], color='darkorange', alpha=0.5, s=s, lw=1, label='C')

plt.legend(scatterpoints=1, loc=5, shadow=False)

similarities = similarities.max() / similarities * 100
similarities[np.isinf(similarities)] = 0
plt.show()
# Out:
# <ipython-input-24-014e479a1b04>:24: RuntimeWarning: divide by zero encountered in true_divide
#   similarities = similarities.max() / similarities * 100

# %%
def calc_confusion_matrix(prediction, test):
    cm = confusion_matrix(test, prediction)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm,)
    disp.plot(cmap="Blues")

# %%
X = preprocessing.normalize(X)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=11, stratify=y)
np.unique(y, return_counts=True)
# Out:
# (array([1, 2, 3]), array([5, 5, 5]))

# %%
parameters = {'n_neighbors':[0,1,2,3,4,5,6,7]}
clf = KNeighborsClassifier()
clf = GridSearchCV(clf, parameters, n_jobs=-1, verbose=10)
clf.fit(X_train, y_train)
clf.best_params_
# Out:
# Fitting 5 folds for each of 8 candidates, totalling 40 fits
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-27-6b8aad20b1c2> in <module>
#       2 clf = KNeighborsClassifier()
#       3 clf = GridSearchCV(clf, parameters, n_jobs=-1, verbose=10)
# ----> 4 clf.fit(X_train, y_train)
#       5 clf.best_params_
#
# ~/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_search.py in fit(self, X, y, groups, **fit_params)
#     839                 return results
#     840
# --> 841             self._run_search(evaluate_candidates)
#     842
#     843             # multimetric is determined here because in the case of a callable
#
# ~/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_search.py in _run_search(self, evaluate_candidates)
#    1294     def _run_search(self, evaluate_candidates):
#    1295         """Search all candidates in param_grid"""
# -> 1296         evaluate_candidates(ParameterGrid(self.param_grid))
#    1297
#    1298
#
# ~/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_search.py in evaluate_candidates(candidate_params, cv, more_results)
#     805                                                        **fit_and_score_kwargs)
#     806                                for (cand_idx, parameters),
# --> 807                                    (split_idx, (train, test)) in product(
#     808                                    enumerate(candidate_params),
#     809                                    enumerate(cv.split(X, y, groups))))
#
# ~/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_split.py in split(self, X, y, groups)
#     330                 .format(self.n_splits, n_samples))
#     331
# --> 332         for train, test in super().split(X, y, groups):
#     333             yield train, test
#     334
#
# ~/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_split.py in split(self, X, y, groups)
#      78         X, y, groups = indexable(X, y, groups)
#      79         indices = np.arange(_num_samples(X))
# ---> 80         for test_index in self._iter_test_masks(X, y, groups):
#      81             train_index = indices[np.logical_not(test_index)]
#      82             test_index = indices[test_index]
#
# ~/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_split.py in _iter_test_masks(self, X, y, groups)
#     691
#     692     def _iter_test_masks(self, X, y=None, groups=None):
# --> 693         test_folds = self._make_test_folds(X, y)
#     694         for i in range(self.n_splits):
#     695             yield test_folds == i
#
# ~/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_split.py in _make_test_folds(self, X, y)
#     660         min_groups = np.min(y_counts)
#     661         if np.all(self.n_splits > y_counts):
# --> 662             raise ValueError("n_splits=%d cannot be greater than the"
#     663                              " number of members in each class."
#     664                              % (self.n_splits))
#
# ValueError: n_splits=5 cannot be greater than the number of members in each class.

# %%
clf = KNeighborsClassifier(n_neighbors=3)
clf.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
prob01 = clf.predict(X_test)
cm = visualize_results(prob01, y_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-97b0bd27adec> in <module>
#       1 prob01 = clf.predict(X_test)
# ----> 2 cm = visualize_results(prob01, y_test)
#
# NameError: name 'visualize_results' is not defined

# %%
calc_confusion_matrix(prob01, y_test)

# %%
df_feature_selection_cat = copy.deepcopy(df)

df_feature_selection_cat = df_feature_selection_cat[["firstorder_Energy", "firstorder_Entropy", "firstorder_Kurtosis", "Gruppe", "firstorder_Skewness"]]

# %%
df_feature_selection_cat.head()
# Out:
#    firstorder_Energy  firstorder_Entropy  firstorder_Kurtosis  Gruppe  \
# 0       5.303353e+07            2.287477            16.190133       1
# 1       6.471675e+06            2.576310             3.691889       1
# 2       1.120756e+07            3.048903             2.750291       1
# 3       1.012544e+08            2.158269             4.483693       2
# 4       7.141937e+07            1.868863            16.662601       3
#
#    firstorder_Skewness
# 0             0.184551
# 1            -1.066357
# 2            -0.158444
# 3            -0.510409
# 4            -1.068774

# %%
# skewness + kurtosis intervall sehr eng.
sns.set(style="ticks")
cmap =sns.color_palette('tab10', n_colors=3)
sns.pairplot(df_feature_selection_cat, hue="Gruppe", palette=cmap)

# %%
# plots für alle verteilungen.

# %%
sns.displot(df, x="firstorder_Skewness", hue="Gruppe",  kind="kde", palette=cmap)

# %%
sns.displot(df, x="firstorder_Skewness", hue="Gruppe")
